# %%
# !pip install -q gpt_2_simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run1')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-9756
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-9756

# %%
text = gpt2.generate(sess,
              length=500,
              temperature=0.9,
              prefix="Black woman standing in front of stairs",
              nsamples=1,
              batch_size=1,
              top_k=20,
              include_prefix=True,)
# Out:
# Black woman standing in front of stairs'92
# The doorbell rings
# '93Well, it'92s you again, madam  Have you seen my brother
# in the yard?
# '93Yes, I have '94
# '93Well, will you come in?'94
# '93Yes '94
# So she went through a back passage, and entered a room, and sat down
# on a low chair, and began by asking me questions
# '93Will you tell me all about it?'94 said I
# '93Yes,'94 said she, '93but only about the two brothers who lived here
# twenty-five years ago  Do you know where they lived?'94
# '93Yes '94
# '93Then you may know where they are?'94
# '93I know that  Then you may know where they have been living '94
# '93Why did they not live here?'94
# '93Because they had no children '94
# '93How so?'94
# '93They had three wives '94
# '93Three wives?'94
# '93Yes '94
# '93How many husbands did they have?'94
# '93One, and a third, and a fourth '94
# '93Where did they live?'94
# '93Here '94
# '93How old were they at the time?'94
# '93They were in their thirties '94
# '93When did they marry?'94
# '93When they were twenty-five '94
# '93How was the marriage arranged? Did they keep any secret?'94
# '93They did not  They were married in the same house that they had
# lived in for the last twenty-five years, and they were both in love
# with the girl who was now living with them '94
# '93How could they not live together, if they were in love?'94
# '93They did not, but they had to have some other woman in the
# same house  But what would become of the girl who had left
# the boy?'94
# '93The boy had nothing to do with it '94
# '93What could the girl be doing away in the country?'94
# '93She had been playing the harp '94
# '93But it seemed that the harp was a relic of another time '94
# '93It is, but you must know that it is very rare these days

# %%
print(text)
# Out:
# None
